# %% [markdown]
# # Практическая работа №1: Исследование алгоритмов формирования аддитивных цепочек
#
# Выполнил студент гр. 0392 Кошмухамбетова Дина, вариант 74.

# %% [markdown]
# # Тема работы
#
# Исследование алгоритмов формирования аддитивных цепочек

# %% [markdown]
# # Цель работы
#
# Формирование представления о аддитивных цепочках, выработать умение составлять и применять алгоритмы для нахождения минимальных
# аддитивных цепочек для заданного числа, привить навык использования
# систем компьютерной математики для реализации алгоритмов.

# %% [markdown]
# # Постановка задачи
#
# Реализовать точные и приближённые алгоритмы нахождения минимальных аддитивных цепочек с использованием системы компьютерной математики SageMath, провести анализ алгоритмов. Полученные результаты
# содержательно проинтерпретировать

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ## №1.  Построить последовательность вычислений бинарным методом и методом множителей для произвольных n > 30.
#
# **1)n = 75**
#
# Бинарный метод:
#
# \\[ m = 2 \\]
# \\[ n = 75 = 64 + 8 + 2 + 1 = 1001011_2 \\]
#
#
# \\[ (x^1)^2 * 1 = x^2 \\]
# \\[ (x^2)^2 * 1 = x^4  \\]
# \\[ (x^4)^2 * x = x^9  \\]
# \\[ (x^9)^2 * 1 = x^{18}  \\]
# \\[ (x^{18})^2 * x = x^{37}  \\]
# \\[ (x^{37})^2 * x = x^{75}  \\]
#
#
# N(operations) = 9
#
# Метод множителей:
#
# \\[ n = 75 = 3 * 25 \\]
# \\[ (x^3)^{25} = x^{75} \\]
# \\[ x, x^2, x^3 - N(operations) = 2 \\]
# \\[ y, y^2, y^3, y^6, y^{12}, y^{24}, y^{25} - N(operations) = 6 \\]
#
# Total = 8
#
# Рассмотрим для другого числа
#
# **n = 123**
#
# \\[ m = 2 \\]
# \\[ n = 123 = 64 + 32 + 16 + 8 + 2 + 1 = 1111011_2 \\]
#
#
# \\[ (x^1)^2 * x = x^3 \\]
# \\[ (x^3)^2 * x = x^7  \\]
# \\[ (x^7)^2 * x = x^{15}  \\]
# \\[ (x^{15})^2 * 1 = x^{30}  \\]
# \\[ (x^{30})^2 * x = x^{61}  \\]
# \\[ (x^{61})^2 * x = x^{123}  \\]
#
#
# N(operations) = 11
#
# Метод множителей:
#
# \\[ n = 123 = 3 * 41 \\]
# \\[ (x^3)^{25} = x^{75} \\]
# \\[ x, x^2, x^3 - N(operations) = 2 \\]
# \\[ y, y^2, y^4, y^5, y^{10}, y^{20}, y^{40}, y^{41}  - N(operations) = 7 \\]
#
# Total = 9
#
# Вывод:
# При выбранных мною числах метод множителей оказался оптимальнее, так как количество операций для него требуется меньше.

# %% [markdown]
# ## №2. Реализовать алгоритм Яо.

# %% [markdown]
# *в работе*

# %% [markdown]
# ## №3. Реализовать алгоритм дробления вектора индексов для нахождения минимальной звёздной цепочки.

# %% [markdown]
# *в отчаянии*

# %% [markdown]
# ## №4. Проверить гипотезу Шольца–Брауэра.
